# %%
##scatter plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
plt.scatter(x,y,color="purple")
plt.title("random scatter plot")
plt.xlabel("x values")
plt.ylabel("y values")
plt.show()

# %%
##pie chart

# %%
labels = ['A','B','C','D']
Sizes = [10,50,48,62]
plt.pie(Sizes,labels=labels,autopct='%1.0f%%')
plt.legend()
plt.show()

# %%
## Creating multiple plots

# %%
fig, axs = plt.subplots(2,2)
axs[0,0].plot([1,2,3,4],[1,4,9,16])
axs[0,1].scatter([1,2,3,4],[1,4,9,16])
axs[1,0].bar([1,2,3,4],[1,4,9,16])
axs[1,1].hist(np.random.randn(100),bins=20)
plt.savefig("plot.png",dpi=300)
plt.grid()
plt.show()

# %%
## 3D plots

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot ([1,2,3],[4,5,5],[7,8,9])

plt.xticks([0,1,2],['A','B','C'])
Plt.Yticks([10,20,30],['LOW','MEDIUM','HIGH'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 6
#       3 ax.plot ([1,2,3],[4,5,5],[7,8,9])
#       5 plt.xticks([0,1,2],['A','B','C'])
# ----> 6 Plt.Yticks([10,20,30],['LOW','MEDIUM','HIGH'])
#       7 plt.show()
#
# NameError: name 'Plt' is not defined

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
fig = plt.figure()
ax =fig.add_subplot(111,projection='3d')
x =np.linspace(-5,5,100)
y =np.sim(x)
z =np.cos(x)

ax.plot(x,y,z,)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 4
#       2 ax =fig.add_subplot(111,projection='3d')
#       3 x =np.linspace(-5,5,100)
# ----> 4 y =np.sim(x)
#       5 z =np.cos(x)
#       7 ax.plot(x,y,z,)
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'sim'

# %%
##3D scatter plot

# %%
fig = plt.figure()
ax =fig.add_subplot(111,projection='3d')
xs =np.random.rand(100)
ys=np.random.rand(100)
zs =np.random.rand(100)

ax.scatter(xs,ys,zs,)
plt.show()

# %%
## 3D Surface Plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


x = np.linspace(-5,5, 100)
y = np.linspace(-5,5, 100)
x , y = np.meshgrid(x, y)

z = np.sin(np.sqrt(x**2, + y**2))

ax.plot_surface(x,y,z, cmap = 'viridis')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


x = np.linspace(-5,5, 100)
y = np.linspace(-5,5, 100)
x , y = np.meshgrid(x, y)

z = np.sin(np.sqrt(x**2, + y**2))

ax.plot_wireframe(x,y,z, color='black')
plt.show()
